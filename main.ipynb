# %%
pip install easyocr opencv-python pillow dateparser
# Out:
# ...
#   Using cached easyocr-1.7.2-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached dateparser-1.2.2-py3-none-any.whl.metadata (29 kB)
# ...
#   Using cached torch-2.8.0-cp313-cp313-win_amd64.whl.metadata (30 kB)
# ...
#   Using cached torchvision-0.23.0-cp313-cp313-win_amd64.whl.metadata (6.1 kB)
# ...
#   Using cached opencv_python_headless-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached python_bidi-0.6.6-cp313-cp313-win_amd64.whl.metadata (5.0 kB)
# ...
#   Using cached shapely-2.1.1-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# ...
#   Using cached pyclipper-1.3.0.post6-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# ...
#   Using cached ninja-1.13.0-py3-none-win_amd64.whl.metadata (5.1 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzlocal-5.3.1-py3-none-any.whl.metadata (7.6 kB)
# ...
# Using cached easyocr-1.7.2-py3-none-any.whl (2.9 MB)
# ...

# %%
pip install --upgrade easyocr opencv-python pillow dateparser tabulate rapidfuzz
# Out:
# ...
#   Using cached pillow-11.3.0-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# ...
# Using cached pillow-11.3.0-cp313-cp313-win_amd64.whl (7.0 MB)
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.6 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 1.6/1.6 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 3.1 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/2 [rapidfuzz]
#    ---------------------------------------- 0/2 [rapidfuzz]
#   Attempting uninstall: pillow
#    ---------------------------------------- 0/2 [rapidfuzz]
#     Found existing installation: pillow 11.1.0
#    ---------------------------------------- 0/2 [rapidfuzz]
#    -------------------- ------------------- 1/2 [pillow]
# ...
